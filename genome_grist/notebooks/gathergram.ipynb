# %%
# %matplotlib inline
import pylab
import pandas as pd
import glob
from collections import defaultdict
import sourmash
from sourmash.lca import lca_utils

# %%
sample_id='SRR1976948'
#sample_id = 'p8808mo9'
#sample_id = 'p8808mo11'
outdir = 'outputs'

# %%
from IPython.display import Markdown as md
from IPython.display import display
md(f"# genome-grist gathergram for metagenome `{sample_id}`")
# Out:
# # genome-grist gathergram for metagenome `SRR1976948`

# %% [markdown]
# ## load mapping summary CSVs and gather CSV

# %%
# load gather CSV
gather_df = pd.read_csv(f'../../{outdir}/genbank/{sample_id}.x.genbank.gather.csv')

# names!
names_df = pd.read_csv(f'../../{outdir}/genbank/{sample_id}.genomes.info.csv')

# connect gather_df to all_df and left_df using 'genome_id'
def fix_name(x):
    return "_".join(x.split('_')[:2]).split('.')[0]

gather_df['genome_id'] = gather_df['name'].apply(fix_name)
names_df['genome_id'] = names_df['acc'].apply(fix_name)

# %%
# CTB bug FIXME - should this ever happen??
# this ensures that only rows that share genome_id are in all the dataframes
in_gather = set(gather_df.genome_id)
names_df = names_df[names_df.genome_id.isin(in_gather)]

# reassign index now that we've maybe dropped rows
gather_df.index = range(len(gather_df))
names_df.index = range(len(names_df))

assert len(names_df) == len(gather_df)

# %%
# re-sort names_df to match gather_df order, using matching genome_id column
names_df.set_index("genome_id")
names_df.reindex(index=gather_df["genome_id"])
_ = names_df.reset_index()

# %%
# load and parse lineages
lineage_files = glob.glob('../../genbank_lineages/*.csv')

lineages_df = pd.DataFrame()

for filename in lineage_files:
    print(f"reading {filename}")
    this_df = pd.read_csv(filename)
    this_df = this_df[this_df.accession.isin(in_gather)]
    lineages_df = lineages_df.append(this_df)
    
lineages_df
# Out:
# reading ../../genbank_lineages/viral_genbank_lineage.csv
# reading ../../genbank_lineages/protozoa_refseq_lineage.csv
# reading ../../genbank_lineages/bacteria_genbank_lineage.csv
# reading ../../genbank_lineages/protozoa_genbank_lineage.csv
# reading ../../genbank_lineages/fungi_genbank_lineage.csv
# reading ../../genbank_lineages/archaea_genbank_lineage.csv
# reading ../../genbank_lineages/viral_refseq_lineage.csv
# reading ../../genbank_lineages/bacteria_refseq_lineage.csv
# reading ../../genbank_lineages/archaea_refseq_lineage.csv
# reading ../../genbank_lineages/fungi_refseq_lineage.csv
#             accession    taxid superkingdom          phylum  \
# 62830   GCA_002890795      316     Bacteria  Proteobacteria
# 62836   GCA_002890955      316     Bacteria  Proteobacteria
# 87568   GCA_003176515      562     Bacteria  Proteobacteria
# 556734  GCA_001887715    29542     Bacteria  Proteobacteria
# 563404  GCA_003445665    41211     Bacteria      Firmicutes
# ...               ...      ...          ...             ...
# 3037    GCA_002839645  2013818      Archaea   Euryarchaeota
# 3041    GCA_002839575  2013822      Archaea   Euryarchaeota
# 5082    GCA_011620825  2517205      Archaea   Euryarchaeota
# 5083    GCA_013329105  2517205      Archaea   Euryarchaeota
# 5255    GCA_011620885  2682607      Archaea   Euryarchaeota
#
#                       class                    order  \
# 62830   Gammaproteobacteria          Pseudomonadales
# 62836   Gammaproteobacteria          Pseudomonadales
# 87568   Gammaproteobacteria         Enterobacterales
# 556734  Deltaproteobacteria       Desulfuromonadales
# 563404           Clostridia            Clostridiales
# ...                     ...                      ...
# 3037        Methanomicrobia       Methanomicrobiales
# 3041        Methanomicrobia       Methanomicrobiales
# 5082         Thermoplasmata  Methanomassiliicoccales
# 5083         Thermoplasmata  Methanomassiliicoccales
# 5255        Methanomicrobia       Methanomicrobiales
#
#                                     family             genus  \
# 62830                     Pseudomonadaceae       Pseudomonas
# 62836                     Pseudomonadaceae       Pseudomonas
# 87568                   Enterobacteriaceae       Escherichia
# 556734                 Desulfuromonadaceae        Pelobacter
# 563404                      Peptococcaceae  Desulfotomaculum
# ...                                    ...               ...
# 3037                                   NaN               NaN
# 3041                                   NaN               NaN
# 5082    Candidatus Methanomethylophilaceae               NaN
# 5083    Candidatus Methanomethylophilaceae               NaN
# 5255                 Methanocorpusculaceae               NaN
#
#                                                   species strain
# 62830                                Pseudomonas stutzeri    NaN
# 62836                                Pseudomonas stutzeri    NaN
# 87568                                    Escherichia coli    NaN
# 556734                            Pelobacter acetylenicus    NaN
# 563404                               Desulfotomaculum sp.    NaN
# ...                                                   ...    ...
# 3037    Methanomicrobiales archaeon HGW-Methanomicrobi...    NaN
# 3041    Methanomicrobiales archaeon HGW-Methanomicrobi...    NaN
# 5082          Candidatus Methanomethylophilaceae archaeon    NaN
# 5083          Candidatus Methanomethylophilaceae archaeon    NaN
# 5255                       Methanocorpusculaceae archaeon    NaN
#
# [162 rows x 10 columns]

# %%
# build a new dataframe that has a single column of lineages in it
def make_combined_lineage(row):
    x = []
    for rank in ('superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species'):
        name = getattr(row, rank)
        # turn NaN/empty into ''
        if pd.isnull(name):
            name = ''
        x.append(lca_utils.LineagePair(rank, name))
    return dict(genome_id=row.accession, combined_lineage=tuple(x))

lineages2_df = lineages_df.apply(make_combined_lineage, axis=1, result_type='expand')

lineages2_df.set_index("genome_id")
lineages2_df.reindex(index=gather_df["genome_id"])
_ = lineages2_df.reset_index()

# %%
# build a merged df that contains stuff from gather_df
merged_lin_df = gather_df.merge(lineages2_df[['genome_id','combined_lineage']], on='genome_id', how='left')

merged_lin_df[["genome_id", "name", "combined_lineage"]]
# Out:
#          genome_id                                               name  \
# 0    GCA_003446605  GCA_003446605.1 Anaerolineaceae bacterium, ASM...
# 1    GCA_003500195  GCA_003500195.1 Clostridiales bacterium, ASM35...
# 2    GCA_002503885  GCA_002503885.1 Methanoculleus marisnigri, ASM...
# 3    GCA_003451675  GCA_003451675.1 Candidatus Atribacteria bacter...
# 4    GCA_003445665  GCA_003445665.1 Desulfotomaculum sp., ASM344566v1
# ..             ...                                                ...
# 157  GCA_002890955  GCA_002890955.1 Pseudomonas stutzeri strain=ST...
# 158  GCA_003194365  GCA_003194365.1 Mesotoga sp. SC_NapDC, ASM3194...
# 159  GCA_002452585  GCA_002452585.1 Kosmotogaceae bacterium UBA681...
# 160  GCA_002329445  GCA_002329445.1 bacterium UBP9_UBA1432, ASM232...
# 161  GCA_002382605  GCA_002382605.1 Synergistaceae bacterium UBA40...
#
#                                       combined_lineage
# 0    ((superkingdom, Bacteria), (phylum, Chloroflex...
# 1    ((superkingdom, Bacteria), (phylum, Firmicutes...
# 2    ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 3    ((superkingdom, Bacteria), (phylum, Candidatus...
# 4    ((superkingdom, Bacteria), (phylum, Firmicutes...
# ..                                                 ...
# 157  ((superkingdom, Bacteria), (phylum, Proteobact...
# 158  ((superkingdom, Bacteria), (phylum, Thermotoga...
# 159  ((superkingdom, Bacteria), (phylum, Thermotoga...
# 160  ((superkingdom, Bacteria), (phylum, ), (class,...
# 161  ((superkingdom, Bacteria), (phylum, Synergiste...
#
# [162 rows x 3 columns]

# %%
pylab.figure(num=None, figsize=(8, 6))
pylab.plot(gather_df.index, gather_df["f_unique_to_query"]*100, '.')

pylab.title('fraction of hashes unique to query')
pylab.xlabel('gather rank order')
pylab.ylabel('f_unique_to_query, as %')
# Out:
# Text(0, 0.5, 'f_unique_to_query, as %')

# %% [markdown]
# ## Taxonomy stuff

# %%
# create function that aggregates various pieces of information by rank & builds a new df
def aggregate_by_rank(df, rank):
    # first, build all the counts
    unique_intersect_by_rank = defaultdict(int)
    best_hashes_by_rank = {}

    def sum_unique(row):
        lin = row.combined_lineage
        unique_hashes = row.unique_intersect_bp

        for rank in ('superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species'):
            poplin = lca_utils.pop_to_rank(lin, rank)
            unique_intersect_by_rank[poplin] += unique_hashes
            
            best_hashes = best_hashes_by_rank.get(poplin, 0)
            if best_hashes < unique_hashes:
                best_hashes_by_rank[poplin] = unique_hashes

    df.apply(sum_unique, axis=1)

    # now do the sorting etc.
    rank_counts = []
    for lin, bp in sorted(unique_intersect_by_rank.items(), key=lambda x: -x[1]):
        if lin[-1].rank == rank:
            
            if rank == 'species':
                name = lin[-1].name
                name = f'{name} ({lin[0].name})'
            else:
                name = lca_utils.display_lineage(lin)

            rank_counts.append(dict(name=name, hashes=bp,
                                    best_hashes=best_hashes_by_rank[lin],
                                    lineage=lin))

    return pd.DataFrame(rank_counts)

# %%
pylab.figure(num=None, figsize=(10, 10))

pylab.plot(gather_df.intersect_bp / 1e6, gather_df.iloc[::-1].index, 'gx', label='hashes classified to this species')
pylab.plot(gather_df.unique_intersect_bp / 1e6, gather_df.iloc[::-1].index, 'ro', label='hashes classified for this genome')

positions = list(gather_df.index)
labels = list(reversed(names_df.ncbi_tax_name))
pylab.yticks(positions, labels, fontsize='small')

pylab.xlabel('number (millions)')
pylab.legend(loc='lower right')
pylab.title(f'{sample_id}: gather hashes vs mapped bp')
pylab.tight_layout()

pylab.savefig(f'/tmp/gather-{sample_id}.pdf')

# %%
rank = 'species'

pylab.figure(num=None, figsize=(10, 10))

rank_counts_df = aggregate_by_rank(merged_lin_df, rank)

plot_df = rank_counts_df[:40]
pylab.plot(plot_df.hashes, plot_df.iloc[::-1].index, 'bo', label='hashes')
pylab.plot(plot_df.best_hashes, plot_df.iloc[::-1].index, 'gx', label='best single genome (hashes)')

positions = list(plot_df.index)
labels = list(reversed(plot_df.name))
pylab.yticks(positions, labels, fontsize='small')

pylab.xlabel('bp')
pylab.legend(loc='lower right')
pylab.title(f'{sample_id}: gather hashes vs mapped bp, by {rank}')
pylab.tight_layout()

figname = f'/tmp/gathertax-{rank}-{sample_id}.png'
print(f'saving to {figname}')
pylab.savefig(figname)
# Out:
# saving to /tmp/gathertax-species-SRR1976948.png

# %%
rank = 'phylum'

pylab.figure(num=None, figsize=(10, 10))

rank_counts_df = aggregate_by_rank(merged_lin_df, rank)

plot_df = rank_counts_df[:40]
pylab.plot(plot_df.hashes, plot_df.iloc[::-1].index, 'bo', label='hashes')
pylab.plot(plot_df.best_hashes, plot_df.iloc[::-1].index, 'gx', label='best single genome (hashes)')

positions = list(plot_df.index)
labels = list(reversed(plot_df.name))
pylab.yticks(positions, labels, fontsize='small')

pylab.xlabel('bp')
pylab.legend(loc='lower right')
pylab.title(f'{sample_id}: gather hashes vs mapped bp, by {rank}')
pylab.tight_layout()

figname = f'/tmp/gathertax-{rank}-{sample_id}.png'
print(f'saving to {figname}')
pylab.savefig(figname)
# Out:
# saving to /tmp/gathertax-phylum-SRR1976948.png
